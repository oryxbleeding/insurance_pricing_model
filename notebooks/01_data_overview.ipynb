# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Daten laden
data = pd.read_csv('../data/raw/insurance_pricing_data.csv')

# Ersten Blick auf die Daten werfen
data.head()
# Out:
#    Age  Gender Occupation        Income Marital_Status  Children    Region  \
# 0   56  female     Doctor  47881.372684       divorced         0  suburban
# 1   69  female     Lawyer  37152.470643       divorced         2     urban
# 2   46    male     Artist  38836.349496        married         0     rural
# 3   32    male    Teacher  37613.463568        married         0     urban
# 4   60    male     Lawyer  70566.482209       divorced         0     rural
#
#   Vehicle_Type  Vehicle_Age       Mileage  Current_Premium Coverage  Claims  \
# 0        Truck           15  65599.191530       692.282790    Basic       0
# 1          Van            8  44410.079619      1029.302175    Basic       0
# 2          SUV           11   7047.192721       585.034718  Premium       0
# 3        Truck            3  51968.774809       504.502641    Basic       0
# 4   Sports Car            8  34584.577625       744.128791  Premium       0
#
#    Regional_Claim_Rate  Economic_Index       Tariff
# 0             0.061998      105.263664   796.940686
# 1             0.099435       98.968987   660.576235
# 2             0.149735      100.232511  1128.627262
# 3             0.088397      107.533741   659.806732
# 4             0.142255      106.420220  1042.924862

# %%
# Datentypen prüfen
data.info()

# Statistische Kennzahlen
data.describe()

# Fehlende Werte überprüfen
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  10000 non-null  int64
#  1   Gender               10000 non-null  object
#  2   Occupation           10000 non-null  object
#  3   Income               10000 non-null  float64
#  4   Marital_Status       10000 non-null  object
#  5   Children             10000 non-null  int64
#  6   Region               10000 non-null  object
#  7   Vehicle_Type         10000 non-null  object
#  8   Vehicle_Age          10000 non-null  int64
#  9   Mileage              10000 non-null  float64
#  10  Current_Premium      10000 non-null  float64
#  11  Coverage             10000 non-null  object
#  12  Claims               10000 non-null  int64
#  13  Regional_Claim_Rate  10000 non-null  float64
#  14  Economic_Index       10000 non-null  float64
#  15  Tariff               10000 non-null  float64
# dtypes: float64(6), int64(4), object(6)
# memory usage: 1.2+ MB
# Age                    0
# Gender                 0
# Occupation             0
# Income                 0
# Marital_Status         0
# Children               0
# Region                 0
# Vehicle_Type           0
# Vehicle_Age            0
# Mileage                0
# Current_Premium        0
# Coverage               0
# Claims                 0
# Regional_Claim_Rate    0
# Economic_Index         0
# Tariff                 0
# dtype: int64

# %%
# Fehlende Werte entfernen (falls vorhanden)
data.dropna(inplace=True)

# %%
# Boxplot für Einkommen
sns.boxplot(x=data['Income'])
plt.show()
